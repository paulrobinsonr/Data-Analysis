# %%
# !pip install pandas

# %%
import pandas as pd

data = {
    "Student": ["A", "B", "C", "D", "E"],
    "Age": [20, 21, 22, 21, 20],
    "Department": ["CSE", "IT", "CSE", "ECE", "IT"],
    "Marks": [85, 72, 91, 68, 78]
}
df=pd.DataFrame(data)

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()

# %%
df["Department"].unique()

# %%
df['Department'].nunique()

# %%
df['Department'].value_counts()

# %%
df.isnull().sum()

# %%
df['Marks'].max()

# %%
df[df['Marks']==df['Marks'].max()]

# %%
df['Marks'] +=2

# %%
df

# %%
df['Marks']=df['Marks']+2

# %%
df

# %%
df['Marks']=df['Marks'].apply(lambda x:x+2)
print(df)

# %%
df.loc[df['Student']=='E', 'Marks'] = df.loc[df['Student']=='E', 'Marks'] + 6
print(df)

# %%
df.at[1,'Marks']+=2
print(df)

# %%
import pandas as pd

data = {
    "Student": [
        "Paul", "John", "Alex", "Mary", "David",
        "Sophia", "James", "Emma", "Daniel", "Olivia"
    ],
    "Math": [85, 72, 90, 88, 76, 95, 67, 82, 79, 91],
    "Science": [80, 78, 95, 84, 70, 96, 65, 88, 81, 92],
    "English": [78, 85, 89, 90, 75, 94, 72, 80, 77, 93],
    "City": [
        "Chennai", "Madurai", "Chennai", "Coimbatore", "Madurai",
        "Chennai", "Salem", "Coimbatore", "Madurai", "Chennai"
    ],
    "Gender": [
        "Male", "Male", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female"
    ],
    "Attendance": [92, 85, 98, 96, 88, 99, 80, 94, 90, 97]
}

df = pd.DataFrame(data)

print(df)

# %%
print(df.loc[df['Student']=='mary'])

# %%
print(df.loc[df['Student']=='Mary','Math'])

# %%
print(df.loc[df["Student"] == "Paul", ["Math", "Science"]])

# %%
print(df.loc[df['Math'] > 90,['Student','Math']])

# %%
print(df.loc[df['City']=='Chennai',['Student','Science','Math','English']])

# %%
print(df.loc[(df['Gender']=='Male') & (df['Math']>80),['Student','City']])

# %%
print(df[df['Gender']=='Male'].value_counts())

# %%
print(df['Gender'].value_counts())

# %%
print(df['Gender'].value_counts(normalize=True))

# %%
print(df[df['Attendance']>90])

# %%
print(df[df['Attendance']>90])

# %%
print(df[(df['Gender']=='Female')& (df['Attendance']>=94)])

# %%
import pandas as pd
T1=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/refs/heads/main/titanic.csv")
#print(T1)
display(T1)

# %%
Survival_rate = T1.groupby('Survived')
display(Survival_rate)
Survival_rate.apply(display)

# %%
import pandas as pd
airbnb = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/airbnb.csv?raw=true', index_col = 'Unnamed: 0')
airbnb
# Out:
#        listing_id                                               name  \
# 0        13740704  Cozy,budget friendly, cable inc, private entra...
# 1        22005115              Two floor apartment near Central Park
# 2        21667615                  Beautiful 1BR in Brooklyn Heights
# 3         6425850                          Spacious, charming studio
# 4        22986519              Bedroom on the lively Lower East Side
# ...           ...                                                ...
# 10014    22307861                        Lovely 1BR Harlem apartment
# 10015      953275                Apartment For Your Holidays in NYC!
# 10016     3452835          Artsy, Garden Getaway in Central Brooklyn
# 10017    23540194     Immaculate townhouse in Clinton Hill, Brooklyn
# 10018    32876011     Private room in a perfect location in the city
#
#          host_id host_name          neighbourhood_full  \
# 0       20583125    Michel         Brooklyn, Flatlands
# ...

# %%
a=airbnb.duplicated().sum()

# %%
print(a)
# Out:
# 13

# %%
airbnb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10019 entries, 0 to 10018
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   listing_id          10019 non-null  int64
#  1   name                10014 non-null  str
#  2   host_id             10019 non-null  int64
#  3   host_name           10017 non-null  str
#  4   neighbourhood_full  10019 non-null  str
#  5   coordinates         10019 non-null  str
#  6   room_type           10019 non-null  str
#  7   price               9781 non-null   str
#  8   number_of_reviews   10019 non-null  int64
#  9   last_review         7944 non-null   str
#  10  reviews_per_month   7944 non-null   float64
#  11  availability_365    10019 non-null  int64
#  12  rating              7944 non-null   float64
#  13  number_of_stays     7944 non-null   float64
#  14  5_stars             7944 non-null   float64
#  15  listing_added       10019 non-null  str
# ...

# %%
b = airbnb[airbnb.duplicated(keep=False)]
display(b)
# Out:
#       listing_id                                               name  \
# 368     17861841                             THE CREATIVE COZY ROOM
# 1145      253806                   Loft Suite @ The Box House Hotel
# 1338    32610834                            Manhattan by the water!
# 1658    35646737                Private Cabins @ Chelsea, Manhattan
# 2118    33346762              2BR Apartment in Brownstone Brooklyn!
# 3007    17861841                             THE CREATIVE COZY ROOM
# 3065    16518377        East Village 1BR Apt with all the amenities
# 3340    35646737                Private Cabins @ Chelsea, Manhattan
# 5025    33831116  Sonder | Stock Exchange | Collected 1BR + Laundry
# 5077    33831116  Sonder | Stock Exchange | Collected 1BR + Laundry
# 5236    29844951                                Cozy Home In Queens
# 5246    22014840       Sunny Bedroom Only 1 Metro Stop to Manhattan
# 5251    19477677                    Huge sunny room next to subway!
# ...

# %%
airbnb.isnull().sum()
# Out:
# listing_id               0
# name                     5
# host_id                  0
# host_name                2
# neighbourhood_full       0
# coordinates              0
# room_type                0
# price                  238
# number_of_reviews        0
# last_review           2075
# reviews_per_month     2075
# availability_365         0
# rating                2075
# number_of_stays       2075
# 5_stars               2075
# listing_added            0
# dtype: int64

# %%
airbnb=airbnb.drop_duplicates(subset="listing_id",keep="first")
airbnb
# Out:
#        listing_id                                               name  \
# 0        13740704  Cozy,budget friendly, cable inc, private entra...
# 1        22005115              Two floor apartment near Central Park
# 2        21667615                  Beautiful 1BR in Brooklyn Heights
# 3         6425850                          Spacious, charming studio
# 4        22986519              Bedroom on the lively Lower East Side
# ...           ...                                                ...
# 10014    22307861                        Lovely 1BR Harlem apartment
# 10015      953275                Apartment For Your Holidays in NYC!
# 10016     3452835          Artsy, Garden Getaway in Central Brooklyn
# 10017    23540194     Immaculate townhouse in Clinton Hill, Brooklyn
# 10018    32876011     Private room in a perfect location in the city
#
#          host_id host_name          neighbourhood_full  \
# 0       20583125    Michel         Brooklyn, Flatlands
# ...

# %%
airbnb[airbnb['number_of_reviews'] > 0][
    ['number_of_reviews',
     'rating',
     'reviews_per_month',
     'last_review']
].head()
# Out:
#    number_of_reviews    rating  reviews_per_month last_review
# 0                 10  4.100954               0.70  2018-12-12
# 1                  1  3.367600               1.00  2019-06-30
# 3                  5  4.763203               0.13  2017-09-23
# 4                 23  3.822591               2.29  2019-06-12
# 5                203  4.478396               2.22  2019-06-20

# %%
airbnb[airbnb['number_of_reviews'] > 0][
    ['number_of_reviews',
     'rating',
     'reviews_per_month',
     'last_review']
].tail()
# Out:
#        number_of_reviews    rating  reviews_per_month last_review
# 10014                  4  4.757555               0.21  2018-05-28
# 10015                 50  4.344704               0.66  2018-05-06
# 10016                 45  3.966214               0.98  2016-11-27
# 10017                  2  4.078581               0.17  2019-05-31
# 10018                  1  4.069096               0.25  2019-03-12

# %%
airbnb[['number_of_reviews',
    'reviews_per_month',
    'rating',
    'number_of_stays',
    '5_stars']].corr(numeric_only=True)
# Out:
#                    number_of_reviews  reviews_per_month    rating  \
# number_of_reviews           1.000000           0.544102 -0.002890
# reviews_per_month           0.544102           1.000000  0.012622
# rating                     -0.002890           0.012622  1.000000
# number_of_stays             1.000000           0.544102 -0.002890
# 5_stars                     0.152615           0.148494  0.362699
#
#                    number_of_stays   5_stars
# number_of_reviews         1.000000  0.152615
# reviews_per_month         0.544102  0.148494
# rating                   -0.002890  0.362699
# number_of_stays           1.000000  0.152615
# 5_stars                   0.152615  1.000000

# %%
airbnb['number_of_stays'].describe()
# Out:
# count    7928.000000
# mean       34.002775
# std        56.110131
# min         1.200000
# 25%         3.600000
# 50%        10.800000
# 75%        38.400000
# max       612.000000
# Name: number_of_stays, dtype: float64

# %%
airbnb[['number_of_reviews','number_of_stays','rating','last_review']].head(20)
# Out:
#     number_of_reviews  number_of_stays    rating last_review
# 0                  10             12.0  4.100954  2018-12-12
# 1                   1              1.2  3.367600  2019-06-30
# 2                   0              NaN       NaN         NaN
# 3                   5              6.0  4.763203  2017-09-23
# 4                  23             27.6  3.822591  2019-06-12
# 5                 203            243.6  4.478396  2019-06-20
# 6                   0              NaN       NaN         NaN
# 7                   2              2.4  4.091228  2018-06-22
# 8                   5              6.0  3.562947  2017-06-25
# 9                   8              9.6  4.695769  2019-04-24
# 10                  5              6.0  3.260108  2018-07-29
# 11                  2              2.4  3.750804  2019-06-03
# 12                 21             25.2  4.315455  2019-06-20
# 13                  0              NaN       NaN         NaN
# ...

# %%
# Identify which values are missing.
# Understand why they're missing.
# Check whether the missingness follows a pattern.
# Decide whether to keep, fill, or drop based on the meaning of the data.
airbnb[['number_of_reviews','number_of_stays','rating','last_review']].tail(20)
# Out:
#        number_of_reviews  number_of_stays    rating last_review
# 9999                  18             21.6  4.344998  2018-05-28
# 10000                  9             10.8  4.761593  2018-09-02
# 10001                 37             44.4  3.028024  2019-06-14
# 10002                 34             40.8  4.984237  2019-05-27
# 10003                  1              1.2  4.377948  2018-11-30
# 10004                  0              NaN       NaN         NaN
# 10005                 10             12.0  4.597951  2019-04-28
# 10006                  1              1.2  4.753029  2016-01-03
# 10007                  0              NaN       NaN         NaN
# 10008                 22             26.4  4.110276  2019-03-22
# 10009                 23             27.6  3.962641  2019-05-06
# 10010                  3              3.6  3.472408  2018-04-09
# 10011                 57             68.4  3.272092  2019-01-01
# 10012                  6              7.2  3.927216  2017-09-05
# ...

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.imshow(airbnb.isnull(), aspect='auto')
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.title("Missing Values")
plt.show()
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.5 MB 7.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 7.3 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.5 MB 7.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.5 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 5.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 7.2 MB/s eta 0:00:01
# ...

# %%
N = int(input())
arr = list(map(int, input().split()))

sorted_arr = sorted(arr)

diff = []

for i in range(N):
    if arr[i] != sorted_arr[i]:
        diff.append(i)

if len(diff) == 1:
    print(diff[0])
else:
    print(-1)
